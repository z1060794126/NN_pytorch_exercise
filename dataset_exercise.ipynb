# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
train_set = torchvision.datasets.FashionMNIST(
    root = './data/FashionMNIST'
    ,train=True
    ,download=True
    ,transform=transforms.Compose([
        transforms.ToTensor()
    ])
    )
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./data/FashionMINST\FashionMNIST\raw\train-images-idx3-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 111.0%
# Extracting ./data/FashionMINST\FashionMNIST\raw\train-labels-idx1-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ./data/FashionMINST\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 159.1%..\torch\csrc\utils\tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
# Extracting ./data/FashionMINST\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to ./data/FashionMINST\FashionMNIST\raw
# Processing...
# Done!

# %%
train_loader = torch.utils.data.DataLoader(train_set,batch_size=10)

# %%
len(train_set)
# Out:
# 60000

# %%
train_set.train_labels
# Out:
# C:\Users\qua\anaconda3\envs\python3\lib\site-packages\torchvision\datasets\mnist.py:45: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# tensor([9, 0, 0,  ..., 3, 0, 5])

# %%
train_set.train_labels.bincount()
# Out:
# tensor([6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000])

# %%
sample = next(iter(train_set))

# %%
len(sample)
# Out:
# 2

# %%
type(sample)
# Out:
# tuple

# %%
image, label = sample

# %%
image.shape
# Out:
# torch.Size([1, 28, 28])

# %%
label = torch.as_tensor(label)

# %%
plt.imshow(image.squeeze(), cmap='gray')
print('label:', label)
# Out:
# label: tensor(9)

# %%
batch = next(iter(train_loader))

# %%
len(batch)
# Out:
# 2

# %%
type(batch)
# Out:
# list

# %%
images, labels = batch

# %%
images.shape
# Out:
# torch.Size([10, 1, 28, 28])

# %%
labels.shape
# Out:
# torch.Size([10])

# %%
print(np.transpose(grid, (1,2,0)).shape)
# Out:
# torch.Size([32, 302, 3])

# %%
grid = torchvision.utils.make_grid(images, nrow=10)

plt.figure(figsize=(15,15))
plt.imshow(np.transpose(grid, (1,2,0)))

print('labels:', labels)
# Out:
# labels: tensor([9, 0, 0, 3, 0, 2, 7, 2, 5, 5])

# %%
train_loader = torch.utils.data.DataLoader(train_set,batch_size=100)

# %%
batch = next(iter(train_loader))
images, labels = batch

# %%
grid = torchvision.utils.make_grid(images, nrow=10)

plt.figure(figsize=(15,15))
plt.imshow(np.transpose(grid, (1,2,0)))

print('labels:', labels)
# Out:
# labels: tensor([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6, 4, 3, 1, 4, 8,
#         4, 3, 0, 2, 4, 4, 5, 3, 6, 6, 0, 8, 5, 2, 1, 6, 6, 7, 9, 5, 9, 2, 7, 3,
#         0, 3, 3, 3, 7, 2, 2, 6, 6, 8, 3, 3, 5, 0, 5, 5, 0, 2, 0, 0, 4, 1, 3, 1,
#         6, 3, 1, 4, 4, 6, 1, 9, 1, 3, 5, 7, 9, 7, 1, 7, 9, 9, 9, 3, 2, 9, 3, 6,
#         4, 1, 1, 8])
